# %% [markdown]
# # Hello World

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Printing in Python

# %% [markdown]
# *Print* is a function. We pass the value/parameter what we want to print in the paranthesis.

# %%
print('Hello World')
print(2+8)
print(3*6.8)
print("end")
# Out:
# Hello World
# 10
# 20.4
# end

# %% [markdown]
# Printing multiple arguments

# %%
print("hey can we meet up at", 5, "PM?")
# Out:
# hey can we meet up at 5 PM?

# %% [markdown]
# # Strings

# %% [markdown]
# Basics of strings
#
# >
#
#
# *   There's no difference between ' ' and " " in python
# *   If we want to include ', enclose it within " "..... (" abc's")

# %%
print("Hey is that abc's car?")
# Out:
# Hey is that abc's car?

# %% [markdown]
# String concatenation

# %%
print("Hello "+"World")
# Out:
# Hello World

# %% [markdown]
# Storing string in a variable

# %%
Name= "Brian"
print("Hey "+ Name)
# Out:
# Hey Brian

# %% [markdown]
# taking string as input

# %%
name=input("Please enter your name: ")
print("Hey "+name)
# Out:
# Please enter your name: Sumanth
# Hey Sumanth
